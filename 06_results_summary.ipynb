# %%
import sys
sys.path.append('sources')
from qubit_circuit import *

# %% [markdown]
# # Loss Function

# %% [markdown]
# ## Single qubit:

# %% [markdown]
# ### Circle dataset, using 'fidelity-chi'

# %% [markdown]
# copiar do outro codigo rsrsrsr ja com o result
# está em 01_single_qubit

# %% [markdown]
# ### Circle dataset, using 'weighted-fidelity-chi'

# %% [markdown]
# copiar do outro codigo rsrsrsr ja com o result
# está em 01_single_qubit

# %% [markdown]
# ### Diamond dataset, using 'fidelity-chi'

# %% [markdown]
# copiar do outro codigo rsrsrsr ja com o result
# está em 01_single_qubit

# %% [markdown]
# ### Diamond dataset, using 'weigheted-fidelity-chi'

# %% [markdown]
# copiar do outro codigo rsrsrsr ja com o result
# está em 01_single_qubit

# %% [markdown]
# ### Wavy lines dataset, using 'fidelity-chi'

# %% [markdown]
# copiar do outro codigo rsrsrsr ja com o result
# está em 01_single_qubit

# %% [markdown]
# ### Wavy lines dataset, using 'weigheted-fidelity-chi'

# %% [markdown]
# copiar do outro codigo rsrsrsr ja com o result
# está em 01_single_qubit

# %% [markdown]
# ## 2 Qubits:

# %% [markdown]
# ## 3 Qubits:

# %% [markdown]
# ### Circle dataset, not entangled

# %% [markdown]
# copiar do cog 02_multiqubit_noentanglement

# %% [markdown]
# ### Diamond dataset, not entangled

# %% [markdown]
# copiar do cog 02_multiqubit_noentanglement

# %% [markdown]
# ### Wavy lines dataset, not entangled

# %% [markdown]
# copiar do cog 02_multiqubit_noentanglement
