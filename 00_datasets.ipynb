# %%
import sys
import warnings
warnings.filterwarnings('ignore') # Its for my shit macbook girls

#To find datasets
sys.path.append('../src') 
from datasets import get_iris_binary, plot_dataset

#Load and prepare the dataset (Setosa vs Versicolor)
X_train, X_test, y_train, y_test = get_iris_binary(task_type="setosa_vs_versicolor")

#Plot the 2D representation
plot_dataset(X_train, y_train)

# %%
# !pip install qiskit qiskit-machine-learning pylatexenc
# Out:
# Collecting qiskit
#   Downloading qiskit-2.2.3-cp39-abi3-macosx_10_12_x86_64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 7.9 MB/s eta 0:00:01
# Collecting qiskit-machine-learning
#   Downloading qiskit_machine_learning-0.8.4-py3-none-any.whl (231 kB)
#      |████████████████████████████████| 231 kB 11.9 MB/s eta 0:00:01
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      |████████████████████████████████| 162 kB 12.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy<3,>=1.17 in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (1.26.4)
# Collecting stevedore>=3.0.0
#   Downloading stevedore-5.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.9 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.5 in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (1.7.3)
# Collecting rustworkx>=0.15.0
#   Downloading rustworkx-0.17.1-cp39-abi3-macosx_10_12_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 13.4 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (4.15.0)
# Collecting dill>=0.3
#   Downloading dill-0.4.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 11.4 MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=40.1 in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (from qiskit-machine-learning) (61.2.0)
# Collecting qiskit
#   Downloading qiskit-1.4.5-cp39-abi3-macosx_10_12_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 22.5 MB/s eta 0:00:01     |████████████████████████        | 4.9 MB 22.5 MB/s eta 0:00:01
# Collecting scikit-learn>=1.2
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
#      |████████████████████████████████| 12.1 MB 2.3 MB/s eta 0:00:011
# Collecting numpy<3,>=1.17
#   Downloading numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
#      |████████████████████████████████| 21.2 MB 2.8 MB/s eta 0:00:011
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (2.8.2)
# Collecting symengine<0.14,>=0.11
#   Downloading symengine-0.13.0-cp39-cp39-macosx_10_13_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 6.8 MB/s eta 0:00:01    |█▍                              | 1.1 MB 4.8 MB/s eta 0:00:06     |██████████████████████████▍     | 21.4 MB 6.8 MB/s eta 0:00:01
# Requirement already satisfied: sympy>=1.3 in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (1.10.1)
# Requirement already satisfied: six>=1.5 in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#      |████████████████████████████████| 309 kB 12.0 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting scipy>=1.5
#   Downloading scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl (39.4 MB)
#      |████████████████████████████████| 39.4 MB 4.1 MB/s eta 0:00:011
# Requirement already satisfied: mpmath>=0.19 in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (from sympy>=1.3->qiskit) (1.2.1)
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136836 sha256=8afc2e11040b9650681781e75528cc3ea27e17309e42559d23f8745b625a8611
#   Stored in directory: /Users/eylulcagla/Library/Caches/pip/wheels/a3/68/66/2f15abd0673d83c02f354115feedeb89c3daed2ac319b11090
# Successfully built pylatexenc
# Installing collected packages: numpy, threadpoolctl, symengine, stevedore, scipy, rustworkx, joblib, dill, scikit-learn, qiskit, qiskit-machine-learning, pylatexenc
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# tensorflow 2.16.2 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.0.2 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 2.0.2 which is incompatible.
# Successfully installed dill-0.4.1 joblib-1.5.3 numpy-2.0.2 pylatexenc-2.10 qiskit-1.4.5 qiskit-machine-learning-0.8.4 rustworkx-0.17.1 scikit-learn-1.6.1 scipy-1.13.1 stevedore-5.5.0 symengine-0.13.0 threadpoolctl-3.6.0

# %%
# !pip install "numpy<2"
# Out:
# Requirement already satisfied: numpy<2 in /Users/eylulcagla/opt/anaconda3/lib/python3.9/site-packages (1.26.4)
